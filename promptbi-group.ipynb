# %% [markdown]
# <a href="https://www.kaggle.com/code/davidckimani/promptbi-group?scriptVersionId=288073361" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/survey-cleaned/2021_rws_cleaned.csv
# /kaggle/input/remote-work-survey/2021_rws.csv
# /kaggle/input/remote-work-survey/2020_rws.csv

# %%
with open("/kaggle/input/remote-work-survey/2021_rws.csv", encoding="utf-8", errors="ignore") as f:
    df = pd.read_csv(f)
df.head()
# Out:
#    Response ID  What year were you born?   What is your gender?    \
# 0            1                        1976                   Male
# 1            2                        1971                   Male
# 2            3                        1978                 Female
# 3            4                        1962                 Female
# 4            5                        1974                   Male
#
#   How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.    \
# 0                                  More than 5 years
# 1                                  More than 5 years
# 2                            Between 6 and 12 months
# 3                              Between 1 and 5 years
# 4                                  More than 5 years
#
#   Which of the following best describes your industry?    \
# 0                                     Other Services
# 1                                       Construction
# 2                            Financial and Insurance
# 3                  Health Care and Social Assistance
# 4                            Financial and Insurance
#
#   Which of the following best describes your current occupation?    \
# 0                  Professionals - ICT Professionals
# 1                  Professionals - ICT Professionals
# 2  Professionals - Business, Human Resource and M...
# 3               Professionals - Health Professionals
# 4                     Managers - Specialist Managers
#
#   How many people are currently employed by your organisation?     \
# 0                                      More than 200
# 1                                      More than 200
# 2                                      More than 200
# 3                                 Between 20 and 199
# 4                                      More than 200
#
#   Which of the following best describes your household?   Metro or Regional  \
# 0                     Couple with dependent children                  Metro
# 1                  Couple with no dependent children                  Metro
# 2                                      Single person                  Metro
# 3          One parent family with dependent children               Regional
# 4                     Couple with dependent children               Regional
#
#   Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.    \
# 0  50% - I spent about half of my time remote wor...
# 1                                                10%
# 2       100% - I spent all of my time remote working
# 3                                                40%
# 4       100% - I spent all of my time remote working
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - Offering remote work helps me to recruit employees  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - My team works well together when they work remotely  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - I find it easy to manage employees remotely (e.g. tasking and monitoring progress)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - I find it easy to manage poor performers remotely  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - I feel well-prepared to manage employees remotely  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - Managing people remotely makes me more focused on results  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   How strongly do you agree or disagree with the following statements?    - I find it easy to contact my employees when they work remotely  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                                NaN
#
#   This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.    Please compare your productivity when you work remotely to when you work at your employers workplace.    Roughly how productive are you, each hour, when you work remotely?    \
# 0  Im 50% more productive when working remotely (...
# 1  Im 50% more productive when working remotely (...
# 2  My productivity is about same when I work remo...
# 3  Im 50% more productive when working remotely (...
# 4       Im 20% more productive when working remotely
#
#   Now think about the productivity of the employees you manage.   Roughly how productive are the employees you manage, each hour, when they work remotely?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Im 50% more productive when working remotely (...
# 4                                                NaN
#
# [5 rows x 109 columns]

# %%
df.shape
# Out:
# (1512, 109)

# %%
df.isna().sum()
# Out:
# Response ID                                                                                                                                                                                                                                                                                                                                                                                    0
# What year were you born?                                                                                                                                                                                                                                                                                                                                                                       0
# What is your gender?                                                                                                                                                                                                                                                                                                                                                                           0
# How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.                                                                                                                                                                                                                                                                     0
# Which of the following best describes your industry?                                                                                                                                                                                                                                                                                                                                           0
#                                                                                                                                                                                                                                                                                                                                                                                             ...
# How strongly do you agree or disagree with the following statements?    - I feel well-prepared to manage employees remotely                                                                                                                                                                                                                                                                  917
# How strongly do you agree or disagree with the following statements?    - Managing people remotely makes me more focused on results                                                                                                                                                                                                                                                          917
# How strongly do you agree or disagree with the following statements?    - I find it easy to contact my employees when they work remotely                                                                                                                                                                                                                                                     917
# This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.    Please compare your productivity when you work remotely to when you work at your employers workplace.    Roughly how productive are you, each hour, when you work remotely?        0
# Now think about the productivity of the employees you manage.   Roughly how productive are the employees you manage, each hour, when they work remotely?                                                                                                                                                                                                                                     815
# Length: 109, dtype: int64

# %%
for col in df.columns[2:]:
    print(f"\n \n", df[col].value_counts())
# Out:
#
#  What is your gender?
# Female                    785
# Male                      723
# I would rather not say      3
# Other                       1
# Name: count, dtype: int64
#
#
#  How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.
# More than 5 years          717
# Between 1 and 5 years      618
# Between 6 and 12 months    177
# Name: count, dtype: int64
#
#
#  Which of the following best describes your industry?
# Financial and Insurance                     204
# Professional, Scientific and Technical      163
# Education and Training                      150
# Information Media and Telecommunications    149
# Other Services                              132
# Health Care and Social Assistance           116
# Retail Trade                                 86
# Construction                                 71
# Administrative and Support                   70
# Manufacturing                                67
# Public Administration and Safety             66
# Wholesale Trade                              50
# Transport, Postal and Warehousing            47
# Arts and Recreation                          35
# Electricity, Gas, Water and Waste            28
# Accommodation and Food                       27
# Rental, Hiring and Real Estate               22
# Mining                                       15
# Agriculture, Forestry and Fishing            14
# Name: count, dtype: int64
#
#
#  Which of the following best describes your current occupation?
# Managers - Specialist Managers                                                              240
# Managers - Chief Executives, General Managers and Legislators                               191
# Professionals - Business, Human Resource and Marketing Professionals                        166
# Professionals - ICT Professionals                                                           108
# Professionals - Education Professionals                                                     103
# Professionals - Design, Engineering, Science and Transport Professionals                     76
# Clerical and administrative workers - General Clerical Workers                               57
# Professionals - Health Professionals                                                         56
# Clerical and administrative workers - Clerical and Office Support Workers                    47
# Professionals - Legal, Social and Welfare Professionals                                      46
# Clerical and administrative workers - Other Clerical and Administrative Workers              46
# Managers - Hospitality, Retail and Service Managers                                          45
# Clerical and administrative workers - Office Managers and Program Administrators             37
# Sales workers - Sales Representatives and Agents                                             31
# Professionals - Arts and Media Professionals                                                 30
# Clerical and administrative workers - Personal Assistants and Secretaries                    22
# Technicians and trades workers - Engineering, ICT and Science Technicians                    18
# Sales workers - Sales Assistants and Salespersons                                            17
# Community and personal service workers - Health and Welfare Support Workers                  16
# Technicians and trades workers - Construction Trades Workers                                 16
# Sales workers - Sales Support Workers                                                        15
# Managers - Farmers and Farm Managers                                                         14
# Technicians and trades workers - Automotive and Engineering Trades Workers                   11
# Clerical and administrative workers - Numerical Clerks                                       11
# Clerical and administrative workers - Inquiry Clerks and Receptionists                       10
# Community and personal service workers - Carers and Aides                                     9
# Technicians and trades workers - Electrotechnology and Telecommunications Trades Workers      9
# Technicians and trades workers - Other Technicians and Trades Workers                         9
# Community and personal service workers - Protective Service Workers                           8
# Community and personal service workers - Hospitality Workers                                  7
# Labourers - Factory Process Workers                                                           6
# Technicians and trades workers - Food Trades Workers                                          5
# Technicians and trades workers - Skilled Animal and Horticultural Workers                     5
# Machinery operators and drivers - Mobile Plant Operators                                      4
# Labourers - Other Labourers                                                                   4
# Labourers - Construction and Mining Labourers                                                 4
# Machinery operators and drivers - Road and Rail Drivers                                       4
# Machinery operators and drivers - Machine and Stationary Plant Operators                      3
# Machinery operators and drivers - Storepersons                                                2
# Labourers - Cleaners and Laundry Workers                                                      2
# Labourers - Farm, Forestry and Garden Workers                                                 1
# Labourers - Food Preparation Assistants                                                       1
# Name: count, dtype: int64
#
#
#  How many people are currently employed by your organisation?
# More than 200                        752
# Between 20 and 199                   445
# Between 5 and 19                     184
# Between 1 and 4                       81
# I am a sole trader/owner-operator     50
# Name: count, dtype: int64
#
#
#  Which of the following best describes your household?
# Couple with dependent children               558
# Couple with no dependent children            418
# Single person                                253
# One parent family with dependent children    105
# Group household                               73
# Multiple family household                     54
# Other one family household                    51
# Name: count, dtype: int64
#
#
#  Metro or Regional
# Metro       1159
# Regional     353
# Name: count, dtype: int64
#
#
#  Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.
# 100% - I spent all of my time remote working          366
# 50% - I spent about half of my time remote working    182
# 20%                                                   142
# Less than 10% of my time                              123
# 90%                                                   111
# 30%                                                   103
# 80%                                                   102
# Rarely or never                                        97
# 40%                                                    85
# 10%                                                    77
# 60%                                                    68
# 70%                                                    56
# Name: count, dtype: int64
#
#
#  How much of your work time would you have preferred to work remotely during the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.
# 100% - All of my time                          389
# 50% - About half of my time                    275
# 20%                                            138
# 80%                                            100
# I would not have preferred to work remotely     91
# 40%                                             88
# 90%                                             87
# 60%                                             81
# Less than 10% of my time                        75
# 30%                                             72
# 70%                                             65
# 10%                                             51
# Name: count, dtype: int64
#
#
#  Thinking about your current job, how much of your work time have you spent working remotely this year?  If you work a 5 day week, each day of remote working equals 20% of your time.
# 100% - I spent all of my time remote working          258
# 50% - I spent about half of my time remote working    165
# 20%                                                   163
# Rarely or never                                       147
# Less than 10% of my time                              112
# 90%                                                   111
# 80%                                                   110
# 30%                                                   108
# 40%                                                   104
# 10%                                                    84
# 60%                                                    83
# 70%                                                    67
# Name: count, dtype: int64
#
#
#  How much of your work time would you have preferred to work remotely so far this year?  If you work a 5 day week, each day of remote working equals 20% of your time.
# 100% - All of my time                          319
# 50% - About half of my time                    278
# 20%                                            160
# 80%                                            114
# I would not have preferred to work remotely    104
# 60%                                             99
# 90%                                             91
# 40%                                             88
# 30%                                             87
# 70%                                             65
# Less than 10% of my time                        59
# 10%                                             48
# Name: count, dtype: int64
#
#
#  Imagine that COVID-19 is cured or eradicated.   Going forward, how much of your work time would you prefer to work remotely?  If you work a 5 day week, each day of remote working equals 20% of your time.
# 50% - About half of my time            279
# 100% - All of my time                  224
# 20%                                    156
# 80%                                    129
# 40%                                    114
# I would prefer not to work remotely    110
# 60%                                    106
# 90%                                     89
# 70%                                     87
# 30%                                     82
# Less than 10% of my time                81
# 10%                                     55
# Name: count, dtype: int64
#
#
#  These questions are about the remote working arrangements in your organisation.  Has your employer changed or updated their policy on remote work since COVID-19?   This means since February/March 2020
# Yes    1103
# No      409
# Name: count, dtype: int64
#
#
#  In the past 6 months, have you ever worked part of your day remotely, and part of it at your employers workplace?
# Yes    921
# No     591
# Name: count, dtype: int64
#
#
#  How often do you work this way?
# Less than 10% of my time       212
# 20%                            140
# 50% - About half of my time    134
# 10%                             95
# 30%                             89
# 40%                             67
# 100% - All of my time           45
# 60%                             43
# 80%                             34
# 70%                             32
# 90%                             30
# Name: count, dtype: int64
#
#
#  How often would you like to work this way?
# Less than 10% of my time       202
# 50% - About half of my time    184
# 20%                            118
# 10%                             77
# 100% - All of my time           70
# 40%                             60
# 80%                             59
# 30%                             56
# 60%                             40
# 70%                             29
# 90%                             26
# Name: count, dtype: int64
#
#
#  Does your employer have a policy that workers must be at the employers workplace some of the time?
# Yes       762
# No        552
# Unsure    198
# Name: count, dtype: int64
#
#
#  How much of your work time does your employers policy require you to be at their workplace?  If you work a 5 day week, 1 day equals 20% of your work time.
# 50% - About half of my time    126
# 20%                            117
# 100% - All of my time          113
# 60%                             85
# 40%                             84
# 80%                             62
# 30%                             60
# 10%                             35
# 90%                             30
# Less than 10% of my time        30
# 70%                             20
# Name: count, dtype: int64
#
#
#  Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My employers remote working policy suits me
# Strongly agree                526
# Somewhat agree                509
# Neither agree nor disagree    277
# Somewhat disagree             113
# Strongly disagree              87
# Name: count, dtype: int64
#
#
#  Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I get to choose how much work I do remotely
# Somewhat agree                461
# Strongly agree                399
# Neither agree nor disagree    244
# Strongly disagree             208
# Somewhat disagree             200
# Name: count, dtype: int64
#
#
#  Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I choose which days I work remotely
# Strongly agree                490
# Somewhat agree                479
# Neither agree nor disagree    208
# Strongly disagree             181
# Somewhat disagree             154
# Name: count, dtype: int64
#
#
#  Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My direct manager has discretion to allow or deny remote work
# Somewhat agree                526
# Strongly agree                460
# Neither agree nor disagree    276
# Somewhat disagree             134
# Strongly disagree             116
# Name: count, dtype: int64
#
#
#  How do you feel about your employers remote working policy?
# Strongly Positive                539
# Somewhat Positive                512
# Neither positive nor negative    297
# Somewhat Negative                108
# Strongly Negative                 56
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation encouraged people to work remotely
# Strongly agree                478
# Somewhat agree                471
# Neither agree nor disagree    315
# Somewhat disagree             139
# Strongly disagree             109
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation was well prepared for me to work remotely
# Somewhat agree                566
# Strongly agree                479
# Neither agree nor disagree    242
# Somewhat disagree             145
# Strongly disagree              80
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was common for people in my organisation to work remotely
# Somewhat agree                555
# Strongly agree                459
# Neither agree nor disagree    235
# Somewhat disagree             155
# Strongly disagree             108
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was easy to get permission to work remotely
# Strongly agree                552
# Somewhat agree                497
# Neither agree nor disagree    270
# Somewhat disagree             108
# Strongly disagree              85
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I could easily collaborate with colleagues when working remotely
# Somewhat agree                590
# Strongly agree                465
# Neither agree nor disagree    241
# Somewhat disagree             165
# Strongly disagree              51
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - Working remotely reduces my chances of promotion
# Neither agree nor disagree    511
# Somewhat disagree             309
# Somewhat agree                279
# Strongly disagree             264
# Strongly agree                149
# Name: count, dtype: int64
#
#
#  Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I take more regular breaks while working remotely
# Somewhat agree                509
# Neither agree nor disagree    345
# Strongly agree                274
# Somewhat disagree             247
# Strongly disagree             137
# Name: count, dtype: int64
#
#
#  Do you think remote working is a positive or a negative for your employer?
# Somewhat Positive                582
# Strongly Positive                445
# Neither positive nor negative    298
# Somewhat Negative                150
# Strongly Negative                 37
# Name: count, dtype: int64
#
#
#  Who is most supportive of remote working in your organisation?
# They are about the same    879
# My direct manger(s)        384
# Senior leadership          249
# Name: count, dtype: int64
#
#
#  Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - My employer would encourage more remote working
# Neither unlikely or likely    410
# Somewhat likely               370
# Somewhat unlikely             280
# Very likely                   239
# Very unlikely                 213
# Name: count, dtype: int64
#
#
#  Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - My employer would make changes to support remote working
# Somewhat likely               479
# Neither unlikely or likely    424
# Very likely                   250
# Somewhat unlikely             183
# Very unlikely                 176
# Name: count, dtype: int64
#
#
#  Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - I would have more choice about whether I work remotely
# Somewhat likely               455
# Neither unlikely or likely    384
# Very likely                   254
# Somewhat unlikely             222
# Very unlikely                 197
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Preparing for work and commuting
# 2.00     409
# 1.00     346
# 3.00     235
# 4.00     101
# 1.50      95
# 0.50      62
# 5.00      60
# 2.50      57
# 0.00      56
# 6.00      26
# 3.50      20
# 8.00      10
# 10.00     10
# 0.25       5
# 7.00       3
# 0.20       2
# 1.25       2
# 16.00      1
# 20.00      1
# 4.50       1
# 9.00       1
# 2.12       1
# 1.75       1
# 0.40       1
# 2.25       1
# 0.70       1
# 12.00      1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Working
# 8.00     616
# 7.00     176
# 9.00     170
# 10.00    117
# 6.00      93
# 7.50      66
# 5.00      54
# 8.50      46
# 4.00      41
# 12.00     29
# 2.00      19
# 3.00      19
# 11.00     17
# 9.50      10
# 20.00      5
# 1.00       5
# 7.60       4
# 10.50      3
# 14.00      3
# 13.00      2
# 15.00      2
# 6.50       2
# 11.50      2
# 1.50       1
# 2.50       1
# 18.00      1
# 0.00       1
# 6.75       1
# 7.35       1
# 8.60       1
# 9.70       1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Caring and domestic responsibilities
# 2.0000     431
# 3.0000     330
# 4.0000     215
# 1.0000     189
# 5.0000     106
# 0.0000      51
# 6.0000      37
# 1.5000      31
# 2.5000      25
# 3.5000      18
# 7.0000      13
# 0.5000      11
# 4.5000      11
# 8.0000       6
# 10.0000      6
# 5.5000       3
# 2.7500       2
# 9.0000       2
# 6.5000       1
# 2.8999       1
# 11.0000      1
# 2.4000       1
# 2.3000       1
# 19.0000      1
# 15.0000      1
# 3.6000       1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Personal and family time
# 4.00     349
# 3.00     298
# 2.00     234
# 5.00     216
# 6.00     107
# 1.00      67
# 3.50      40
# 7.00      34
# 8.00      29
# 2.50      23
# 4.50      22
# 5.50      16
# 1.50      12
# 6.50      11
# 7.50       9
# 0.00       8
# 10.00      6
# 9.00       6
# 0.50       4
# 12.00      3
# 12.50      2
# 11.00      1
# 8.50       1
# 14.00      1
# 3.75       1
# 2.25       1
# 11.50      1
# 2.89       1
# 5.30       1
# 5.75       1
# 2.75       1
# 5.80       1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Sleep
# 8.00     632
# 7.00     341
# 6.00     171
# 9.00     100
# 5.00      46
# 10.00     45
# 7.50      40
# 4.00      30
# 6.50      16
# 8.50      12
# 2.00      12
# 1.00       9
# 3.00       8
# 11.00      6
# 12.00      6
# 0.00       4
# 9.50       3
# 5.50       3
# 14.00      2
# 10.50      2
# 7.70       1
# 8.75       1
# 17.00      1
# 8.90       1
# 7.75       1
# 11.50      1
# 4.50       1
# 15.00      1
# 9.90       1
# 7.25       1
# 7.80       1
# 20.00      1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Preparing for work and commuting
# 0.00     536
# 0.50     299
# 1.00     289
# 2.00     124
# 4.00      54
# 3.00      52
# 5.00      44
# 6.00      26
# 0.25      12
# 8.00       9
# 1.50       9
# 7.00       7
# 10.00      4
# 2.50       4
# 16.00      3
# 0.20       3
# 0.10       3
# 0.30       2
# 12.00      2
# 20.00      1
# 9.00       1
# 0.40       1
# 3.50       1
# 24.00      1
# 0.75       1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Working
# 8.00     505
# 9.00     211
# 10.00    199
# 7.00     149
# 6.00      97
# 12.00     54
# 5.00      54
# 7.50      50
# 8.50      41
# 4.00      35
# 3.00      22
# 11.00     21
# 9.50      18
# 2.00      16
# 10.50      6
# 1.00       5
# 13.00      4
# 15.00      3
# 14.00      2
# 16.00      2
# 24.00      2
# 6.50       2
# 8.75       2
# 0.00       1
# 18.00      1
# 23.00      1
# 2.50       1
# 11.50      1
# 9.75       1
# 7.35       1
# 7.60       1
# 20.00      1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Caring and domestic responsibilities
# 2.00     369
# 3.00     363
# 4.00     279
# 1.00     139
# 5.00     124
# 6.00      37
# 2.50      36
# 0.00      35
# 1.50      33
# 3.50      15
# 8.00      14
# 4.50      13
# 7.00      13
# 0.50       5
# 10.00      5
# 5.50       4
# 3.70       2
# 9.00       2
# 3.75       1
# 12.00      1
# 0.20       1
# 4.25       1
# 17.00      1
# 6.50       1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Personal and family time
# 4.00     338
# 5.00     255
# 3.00     237
# 2.00     160
# 6.00     153
# 4.50      55
# 7.00      51
# 5.50      42
# 3.50      36
# 8.00      36
# 1.00      34
# 6.50      23
# 2.50      11
# 7.50      10
# 0.00      10
# 1.50       9
# 8.50       7
# 9.00       4
# 10.00      4
# 5.25       3
# 11.00      3
# 9.50       2
# 4.25       2
# 3.70       2
# 4.70       2
# 5.80       2
# 20.00      2
# 13.60      1
# 14.00      1
# 13.00      1
# 24.00      1
# 5.39       1
# 4.90       1
# 4.69       1
# 3.60       1
# 12.50      1
# 6.75       1
# 5.20       1
# 12.00      1
# Name: count, dtype: int64
#
#
#  Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Sleep
# 8.00     666
# 7.00     302
# 6.00     131
# 9.00     122
# 10.00     66
# 7.50      40
# 5.00      38
# 4.00      34
# 8.50      20
# 2.00      19
# 3.00      13
# 6.50      12
# 12.00      8
# 1.00       7
# 9.50       7
# 0.00       4
# 11.00      4
# 14.00      3
# 13.00      1
# 6.70       1
# 7.75       1
# 4.50       1
# 5.50       1
# 9.40       1
# 10.50      1
# Name: count, dtype: int64
#
#
#  Imagine your employer offered you the option to work remotely whenever you chose, in return for negotiating a pay cut that you both agree on.  Would you be interested in negotiating?
# No     1027
# Yes     485
# Name: count, dtype: int64
#
#
#  What is the biggest pay cut you would accept?   Please give your answer as a percentage.
# 0.10    140
# 0.05    106
# 0.20     62
# 0.02     21
# 0.15     20
# 0.50     18
# 0.01     18
# 0.60     12
# 0.40      9
# 0.30      7
# 0.99      7
# 0.80      6
# 0.03      5
# 0.12      4
# 0.45      4
# 0.25      4
# 0.23      3
# 0.75      3
# 0.16      3
# 0.55      3
# 0.56      3
# 0.90      3
# 0.34      2
# 0.89      2
# 0.08      2
# 0.06      2
# 0.57      2
# 0.70      2
# 1.00      1
# 0.04      1
# 0.28      1
# 0.33      1
# 0.78      1
# 0.65      1
# 0.35      1
# 0.64      1
# 0.43      1
# 0.13      1
# 0.24      1
# 0.67      1
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My caring responsibilities
# Stayed about the same     546
# Not a barrier for me      404
# Somewhat improved         279
# Significantly improved    146
# Somewhat worsened         104
# Significantly worsened     33
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Connectivity (for example internet)
# Stayed about the same     598
# Not a barrier for me      294
# Somewhat improved         289
# Somewhat worsened         160
# Significantly improved    129
# Significantly worsened     42
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My organisation's software and systems
# Stayed about the same     613
# Somewhat improved         357
# Not a barrier for me      234
# Significantly improved    140
# Somewhat worsened         128
# Significantly worsened     40
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Difficulty collaborating remotely
# Stayed about the same     517
# Somewhat improved         350
# Not a barrier for me      263
# Somewhat worsened         189
# Significantly improved    121
# Significantly worsened     72
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Poor management
# Stayed about the same     609
# Not a barrier for me      336
# Somewhat improved         218
# Somewhat worsened         156
# Significantly improved    114
# Significantly worsened     79
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - IT equipment (computer or printer)
# Stayed about the same     624
# Somewhat improved         296
# Not a barrier for me      240
# Somewhat worsened         174
# Significantly improved    123
# Significantly worsened     55
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Feeling left out and/or isolated
# Stayed about the same     546
# Not a barrier for me      324
# Somewhat worsened         267
# Somewhat improved         186
# Significantly worsened     98
# Significantly improved     91
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Extra costs
# Stayed about the same     541
# Not a barrier for me      319
# Somewhat improved         279
# Somewhat worsened         182
# Significantly improved    132
# Significantly worsened     59
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Cyber security
# Stayed about the same     661
# Not a barrier for me      319
# Somewhat improved         250
# Somewhat worsened         126
# Significantly improved    110
# Significantly worsened     46
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - I have tasks that can't be done remotely
# Stayed about the same     600
# Not a barrier for me      377
# Somewhat improved         234
# Somewhat worsened         143
# Significantly improved     84
# Significantly worsened     74
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My workspace (e.g. suitable chair, lighting, noise levels, facilities)
# Stayed about the same     577
# Somewhat improved         314
# Not a barrier for me      270
# Somewhat worsened         161
# Significantly improved    129
# Significantly worsened     61
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Motivation
# Stayed about the same     518
# Somewhat improved         339
# Not a barrier for me      235
# Somewhat worsened         227
# Significantly improved    132
# Significantly worsened     61
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Management discourages remote working
# Stayed about the same     487
# Not a barrier for me      391
# Somewhat improved         271
# Somewhat worsened         155
# Significantly improved    132
# Significantly worsened     76
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My living situation (e.g. location, home size, who I live with)
# Stayed about the same     643
# Not a barrier for me      349
# Somewhat improved         270
# Significantly improved    119
# Somewhat worsened          88
# Significantly worsened     43
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Lack of remote working skills
# Stayed about the same     529
# Not a barrier for me      453
# Somewhat improved         282
# Significantly improved    122
# Somewhat worsened          85
# Significantly worsened     41
# Name: count, dtype: int64
#
#
#  Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My health and safety when working remotely
# Stayed about the same     563
# Somewhat improved         312
# Not a barrier for me      301
# Significantly improved    185
# Somewhat worsened         116
# Significantly worsened     35
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Difficulty collaborating with remote colleagues ; Lack of privacy
# Difficulty collaborating with remote colleagues    356
# Interruptions                                      282
# Noisy work environment                             148
# Lack of privacy                                    110
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Difficulty collaborating with remote colleagues ; Lack of privacy
# Noisy work environment                             258
# Lack of privacy                                    244
# Difficulty collaborating with remote colleagues    210
# Interruptions                                      184
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Lack of privacy
# Connectivity/internet issues                   266
# Problems with audio-visual setup               242
# Lack of appropriate work and meeting spaces    236
# Lack of privacy                                152
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Lack of privacy
# Connectivity/internet issues                   276
# Lack of privacy                                253
# Lack of appropriate work and meeting spaces    212
# Problems with audio-visual setup               155
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty innovating
# Interruptions                                  310
# Connectivity/internet issues                   227
# Difficulty innovating                          183
# Lack of appropriate work and meeting spaces    176
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty innovating
# Connectivity/internet issues                   249
# Interruptions                                  228
# Lack of appropriate work and meeting spaces    215
# Difficulty innovating                          204
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Connectivity/internet issues ; Difficulty collaborating with remote colleagues ; Difficulty innovating ; Lack of privacy
# Difficulty collaborating with remote colleagues    319
# Connectivity/internet issues                       232
# Difficulty innovating                              181
# Lack of privacy                                    164
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Connectivity/internet issues ; Difficulty collaborating with remote colleagues ; Difficulty innovating ; Lack of privacy
# Connectivity/internet issues                       296
# Lack of privacy                                    241
# Difficulty innovating                              192
# Difficulty collaborating with remote colleagues    167
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating
# Interruptions                   263
# Connectivity/internet issues    253
# Noisy work environment          206
# Difficulty innovating           174
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating
# Noisy work environment          266
# Connectivity/internet issues    263
# Interruptions                   190
# Difficulty innovating           177
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup
# Interruptions                                  263
# Noisy work environment                         214
# Lack of appropriate work and meeting spaces    211
# Problems with audio-visual setup               208
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup
# Noisy work environment                         274
# Lack of appropriate work and meeting spaces    219
# Interruptions                                  218
# Problems with audio-visual setup               185
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues
# Interruptions                                      292
# Difficulty collaborating with remote colleagues    253
# Connectivity/internet issues                       193
# Problems with audio-visual setup                   158
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues
# Interruptions                                      297
# Connectivity/internet issues                       260
# Problems with audio-visual setup                   183
# Difficulty collaborating with remote colleagues    156
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Lack of appropriate work and meeting spaces ; Difficulty innovating ; Lack of privacy
# Noisy work environment                         284
# Difficulty innovating                          254
# Lack of appropriate work and meeting spaces    219
# Lack of privacy                                139
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Lack of appropriate work and meeting spaces ; Difficulty innovating ; Lack of privacy
# Difficulty innovating                          236
# Lack of appropriate work and meeting spaces    228
# Noisy work environment                         228
# Lack of privacy                                204
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues
# Difficulty collaborating with remote colleagues    261
# Noisy work environment                             260
# Connectivity/internet issues                       198
# Lack of appropriate work and meeting spaces        177
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues
# Connectivity/internet issues                       285
# Noisy work environment                             283
# Lack of appropriate work and meeting spaces        203
# Difficulty collaborating with remote colleagues    125
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Problems with audio-visual setup ; Difficulty innovating ; Lack of privacy
# Interruptions                       323
# Problems with audio-visual setup    231
# Difficulty innovating               227
# Lack of privacy                     115
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Problems with audio-visual setup ; Difficulty innovating ; Lack of privacy
# Interruptions                       237
# Lack of privacy                     230
# Problems with audio-visual setup    217
# Difficulty innovating               212
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating
# Difficulty collaborating with remote colleagues    316
# Problems with audio-visual setup                   224
# Lack of appropriate work and meeting spaces        204
# Difficulty innovating                              152
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating
# Lack of appropriate work and meeting spaces        284
# Problems with audio-visual setup                   273
# Difficulty innovating                              185
# Difficulty collaborating with remote colleagues    154
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Problems with audio-visual setup ; Lack of privacy
# Noisy work environment              269
# Problems with audio-visual setup    241
# Connectivity/internet issues        240
# Lack of privacy                     146
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Problems with audio-visual setup ; Lack of privacy
# Noisy work environment              270
# Connectivity/internet issues        234
# Lack of privacy                     216
# Problems with audio-visual setup    176
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues ; Lack of privacy
# Difficulty collaborating with remote colleagues    320
# Interruptions                                      303
# Lack of appropriate work and meeting spaces        164
# Lack of privacy                                    109
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues ; Lack of privacy
# Interruptions                                      253
# Lack of privacy                                    252
# Lack of appropriate work and meeting spaces        220
# Difficulty collaborating with remote colleagues    171
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating
# Difficulty collaborating with remote colleagues    288
# Noisy work environment                             281
# Problems with audio-visual setup                   204
# Difficulty innovating                              123
# Name: count, dtype: int64
#
#
#  Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating
# Noisy work environment                             307
# Problems with audio-visual setup                   233
# Difficulty innovating                              191
# Difficulty collaborating with remote colleagues    165
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?   - On days when I work remotely I feel better
# Somewhat agree                495
# Neither agree nor disagree    446
# Strongly agree                404
# Somewhat disagree             122
# Strongly disagree              45
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?   - On days when I work remotely I am more active
# Somewhat agree                486
# Neither agree nor disagree    384
# Strongly agree                375
# Somewhat disagree             187
# Strongly disagree              80
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?   - I feel better on days when I see my colleagues in person
# Somewhat agree                536
# Neither agree nor disagree    498
# Strongly agree                268
# Somewhat disagree             134
# Strongly disagree              76
# Name: count, dtype: int64
#
#
#  Do you manage people as part of your current job?
# No     815
# Yes    697
# Name: count, dtype: int64
#
#
#  Do employees you manage ever work remotely?
# Yes    595
# No     102
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - I have discretion to offer or deny remote work to employees I manage
# Somewhat agree                237
# Strongly agree                147
# Neither agree nor disagree    118
# Somewhat disagree              59
# Strongly disagree              34
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees
# Somewhat agree                255
# Strongly agree                152
# Neither agree nor disagree    141
# Somewhat disagree              31
# Strongly disagree              16
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - Offering remote work helps me to recruit employees
# Somewhat agree                219
# Neither agree nor disagree    196
# Strongly agree                132
# Somewhat disagree              32
# Strongly disagree              16
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - My team works well together when they work remotely
# Somewhat agree                279
# Strongly agree                159
# Neither agree nor disagree    102
# Somewhat disagree              44
# Strongly disagree              11
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - I find it easy to manage employees remotely (e.g. tasking and monitoring progress)
# Somewhat agree                241
# Strongly agree                163
# Neither agree nor disagree    105
# Somewhat disagree              66
# Strongly disagree              20
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - I find it easy to manage poor performers remotely
# Somewhat agree                188
# Neither agree nor disagree    157
# Somewhat disagree             115
# Strongly agree                 98
# Strongly disagree              37
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - I feel well-prepared to manage employees remotely
# Somewhat agree                243
# Strongly agree                156
# Neither agree nor disagree    139
# Somewhat disagree              52
# Strongly disagree               5
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - Managing people remotely makes me more focused on results
# Somewhat agree                256
# Strongly agree                151
# Neither agree nor disagree    138
# Somewhat disagree              43
# Strongly disagree               7
# Name: count, dtype: int64
#
#
#  How strongly do you agree or disagree with the following statements?    - I find it easy to contact my employees when they work remotely
# Somewhat agree                253
# Strongly agree                171
# Neither agree nor disagree     98
# Somewhat disagree              56
# Strongly disagree              17
# Name: count, dtype: int64
#
#
#  This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.    Please compare your productivity when you work remotely to when you work at your employers workplace.    Roughly how productive are you, each hour, when you work remotely?
# My productivity is about same when I work remotely         330
# Im 50% more productive when working remotely (or more)     278
# Im 30% more productive when working remotely               237
# Im 20% more productive when working remotely               229
# Im 10% more productive when working remotely               111
# Im 40% more productive when working remotely               111
# Im 20% less productive when working remotely                74
# Im 10% less productive when working remotely                71
# Im 30% less productive when working remotely                38
# Im 50% less productive when working remotely (or worse)     23
# Im 40% less productive when working remotely                10
# Name: count, dtype: int64
#
#
#  Now think about the productivity of the employees you manage.   Roughly how productive are the employees you manage, each hour, when they work remotely?
# Im 50% more productive when working remotely (or more)     125
# Im 30% more productive when working remotely               117
# Im 20% more productive when working remotely               114
# My productivity is about same when I work remotely         112
# Im 40% more productive when working remotely                73
# Im 10% more productive when working remotely                69
# Im 20% less productive when working remotely                33
# Im 10% less productive when working remotely                27
# Im 30% less productive when working remotely                17
# Im 50% less productive when working remotely (or worse)      6
# Im 40% less productive when working remotely                 4
# Name: count, dtype: int64

# %%
gender_count= df["What is your gender?  "].value_counts()
gender_count
# Out:
# What is your gender?
# Female                    785
# Male                      723
# I would rather not say      3
# Other                       1
# Name: count, dtype: int64

# %%
years_of_experience = df["How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.  "].value_counts()
years_of_experience
# Out:
# How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.
# More than 5 years          717
# Between 1 and 5 years      618
# Between 6 and 12 months    177
# Name: count, dtype: int64

# %% [markdown]
# ## Jackline

# %%
#this is a test line

# %% [markdown]
# ## Nelly

# %% [markdown]
# ## Mwangi

# %% [markdown]
# ## Faisa

# %% [markdown]
# ## Okelo

# %%
group_size = 18

cols = df.columns.tolist()
col_groups = [cols[i:i +group_size] for i in range(0,len(cols), group_size)]

print(f"total groups: {len(col_groups)}")
for i, group in enumerate(col_groups, start=1):
    print(f"Group {i}: {len(group)} cols")
    print(group)
# Out:
# total groups: 7
# Group 1: 18 cols
# ['Response ID', 'What year were you born?  ', 'What is your gender?  ', 'How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.  ', 'Which of the following best describes your industry?  ', 'Which of the following best describes your current occupation?  ', 'How many people are currently employed by your organisation?   ', 'Which of the following best describes your household?  ', 'Metro or Regional', 'Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'How much of your work time would you have preferred to work remotely during the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'Thinking about your current job, how much of your work time have you spent working remotely this year?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'How much of your work time would you have preferred to work remotely so far this year?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'Imagine that COVID-19 is cured or eradicated.   Going forward, how much of your work time would you prefer to work remotely?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'These questions are about the remote working arrangements in your organisation.  Has your employer changed or updated their policy on remote work since COVID-19?   This means since February/March 2020  ', 'In the past 6 months, have you ever worked part of your day remotely, and part of it at your employers workplace?', 'How often do you work this way?  ', 'How often would you like to work this way?  ']
# Group 2: 18 cols
# ['Does your employer have a policy that workers must be at the employers workplace some of the time?  ', 'How much of your work time does your employers policy require you to be at their workplace?  If you work a 5 day week, 1 day equals 20% of your work time.  ', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My employers remote working policy suits me', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I get to choose how much work I do remotely', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I choose which days I work remotely', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My direct manager has discretion to allow or deny remote work', 'How do you feel about your employers remote working policy?  ', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation encouraged people to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation was well prepared for me to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was common for people in my organisation to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was easy to get permission to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I could easily collaborate with colleagues when working remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - Working remotely reduces my chances of promotion', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I take more regular breaks while working remotely', 'Do you think remote working is a positive or a negative for your employer?  ', 'Who is most supportive of remote working in your organisation?  ', 'Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - My employer would encourage more remote working', 'Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - My employer would make changes to support remote working']
# Group 3: 18 cols
# ['Imagine that COVID-19 is cured or eradicated.    How likely would you consider the following statements?   - I would have more choice about whether I work remotely', "Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Preparing for work and commuting", "Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Working", "Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Caring and domestic responsibilities", "Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Personal and family time", "Think about your experience this year. On a day when you attend your employer's workplace, how many hours would you spend doing the following activities?   For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Sleep", 'Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Preparing for work and commuting', 'Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Working', 'Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Caring and domestic responsibilities', 'Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Personal and family time', 'Think about your experience this year. On a day when you work remotely, how many hours would you spend doing the following activities?  For example, a response of 1 means 1 hour.  A response of 0.5 means half an hour.   Your responses should add to 24 hours.   - Sleep', 'Imagine your employer offered you the option to work remotely whenever you chose, in return for negotiating a pay cut that you both agree on.  Would you be interested in negotiating?   ', 'What is the biggest pay cut you would accept?   Please give your answer as a percentage.  ', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My caring responsibilities', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Connectivity (for example internet)', "Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My organisation's software and systems", 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Difficulty collaborating remotely', 'Have the f ...
# Group 4: 18 cols
# ['Have the following barriers to remote working improved or worsened for you over the past 6 months?   - IT equipment (computer or printer)', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Feeling left out and/or isolated', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Extra costs', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Cyber security', "Have the following barriers to remote working improved or worsened for you over the past 6 months?   - I have tasks that can't be done remotely", 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My workspace (e.g. suitable chair, lighting, noise levels, facilities)', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Motivation', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Management discourages remote working', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My living situation (e.g. location, home size, who I live with)', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - Lack of remote working skills', 'Have the following barriers to remote working improved or worsened for you over the past 6 months?   - My health and safety when working remotely', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Difficulty collaborating with remote colleagues ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Difficulty collaborating with remote colleagues ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty innovating', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty innovating', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Connectivity/internet issues ; Difficulty collaborating with remote colleagues ; Difficulty innovating ; Lack of privacy']
# Group 5: 18 cols
# ['Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Connectivity/internet issues ; Difficulty collaborating with remote colleagues ; Difficulty innovating ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Connectivity/internet issues ; Difficulty innovating', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Interruptions ; Lack of appropriate work and meeting spaces ; Problems with audio-visual setup', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Connectivity/internet issues ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Lack of appropriate work and meeting spaces ; Difficulty innovating ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Lack of appropriate work and meeting spaces ; Difficulty innovating ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Connectivity/internet issues ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Interruptions ; Problems with audio-visual setup ; Difficulty innovating ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Problems with audio-visual setup ; Difficulty innovating ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Lack of appropriate work and meeting spaces ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating', 'Think about when you worked a ...
# Group 6: 18 cols
# ['Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Interruptions ; Lack of appropriate work and meeting spaces ; Difficulty collaborating with remote colleagues ; Lack of privacy', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the biggest barriers of working this way? - Noisy work environment ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating', 'Think about when you worked at your employers workplace and some of your colleagues were working remotely. What were the smallest barriers of working this way? - Noisy work environment ; Problems with audio-visual setup ; Difficulty collaborating with remote colleagues ; Difficulty innovating', 'How strongly do you agree or disagree with the following statements?   - On days when I work remotely I feel better', 'How strongly do you agree or disagree with the following statements?   - On days when I work remotely I am more active', 'How strongly do you agree or disagree with the following statements?   - I feel better on days when I see my colleagues in person', 'Do you manage people as part of your current job?  ', 'Do employees you manage ever work remotely?  ', 'How strongly do you agree or disagree with the following statements?    - I have discretion to offer or deny remote work to employees I manage', 'How strongly do you agree or disagree with the following statements?    - Offering remote work helps me retain employees', 'How strongly do you agree or disagree with the following statements?    - Offering remote work helps me to recruit employees', 'How strongly do you agree or disagree with the following statements?    - My team works well together when they work remotely', 'How strongly do you agree or disagree with the following statements?    - I find it easy to manage employees remotely (e.g. tasking and monitoring progress)', 'How strongly do you agree or disagree with the following statements?    - I find it easy to manage poor performers remotely', 'How strongly do you agree or disagree with the following statements?    - I feel well-prepared to manage employees remotely', 'How strongly do you agree or disagree with the following statements?    - Managing people remotely makes me more focused on results', 'How strongly do you agree or disagree with the following statements?    - I find it easy to contact my employees when they work remotely', 'This question is about your productivity. Productivity means what you produce for each hour that you work. It includes the amount of work you achieve each hour, and the quality of your work each hour.    Please compare your productivity when you work remotely to when you work at your employers workplace.    Roughly how productive are you, each hour, when you work remotely?  ']
# Group 7: 1 cols
# ['Now think about the productivity of the employees you manage.   Roughly how productive are the employees you manage, each hour, when they work remotely?  ']

# %%
print(df.columns.tolist())
# Out:
# ['Response ID', 'What year were you born?  ', 'What is your gender?  ', 'How long have you been in your current job?  If you have more than one job, please answer all questions for your main job.  ', 'Which of the following best describes your industry?  ', 'Which of the following best describes your current occupation?  ', 'How many people are currently employed by your organisation?   ', 'Which of the following best describes your household?  ', 'Metro or Regional', 'Thinking about your current job, how much of your work time did you spend working remotely in the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'How much of your work time would you have preferred to work remotely during the last quarter of last year?   This means October-December 2020  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'Thinking about your current job, how much of your work time have you spent working remotely this year?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'How much of your work time would you have preferred to work remotely so far this year?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'Imagine that COVID-19 is cured or eradicated.   Going forward, how much of your work time would you prefer to work remotely?  If you work a 5 day week, each day of remote working equals 20% of your time.  ', 'These questions are about the remote working arrangements in your organisation.  Has your employer changed or updated their policy on remote work since COVID-19?   This means since February/March 2020  ', 'In the past 6 months, have you ever worked part of your day remotely, and part of it at your employers workplace?', 'How often do you work this way?  ', 'How often would you like to work this way?  ', 'Does your employer have a policy that workers must be at the employers workplace some of the time?  ', 'How much of your work time does your employers policy require you to be at their workplace?  If you work a 5 day week, 1 day equals 20% of your work time.  ', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My employers remote working policy suits me', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I get to choose how much work I do remotely', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - I choose which days I work remotely', 'Thinking about your employers policy on remote working, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My direct manager has discretion to allow or deny remote work', 'How do you feel about your employers remote working policy?  ', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation encouraged people to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - My organisation was well prepared for me to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was common for people in my organisation to work remotely', 'Thinking about remote working in the last 6 months, how strongly do you agree or disagree with the following statements?   Please select a single response per row   - It was easy to get perm ...
